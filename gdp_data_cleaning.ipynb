# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
gdp_file = "GDP By Country.csv"
gdp_df = pd.read_csv(gdp_file)
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
gdp_df.drop('2018',axis=1, inplace=True)
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
clean_gdp = gdp_df.dropna()
final_gdp = clean_gdp.drop(clean_gdp.columns.to_series()["1960":"1989"],axis=1)
final_gdp.head()
# Out:
#    Country Name Country Code     Indicator Name  Indicator Code          1990  \
# 11    Australia          AUS  GDP (current US$)  NY.GDP.MKTP.CD  3.108380e+11
# 12      Austria          AUT  GDP (current US$)  NY.GDP.MKTP.CD  1.664630e+11
# 14      Burundi          BDI  GDP (current US$)  NY.GDP.MKTP.CD  1.132101e+09
# 15      Belgium          BEL  GDP (current US$)  NY.GDP.MKTP.CD  2.064310e+11
# 16        Benin          BEN  GDP (current US$)  NY.GDP.MKTP.CD  1.959965e+09
#
#             1991          1992          1993          1994          1995  ...  \
# 11  3.253580e+11  3.248780e+11  3.115290e+11  3.222010e+11  3.672160e+11  ...
# 12  1.737940e+11  1.950780e+11  1.903800e+11  2.035350e+11  2.410380e+11  ...
# 14  1.167398e+09  1.083038e+09  9.386326e+08  9.250306e+08  1.000428e+09  ...
# 15  2.116380e+11  2.360380e+11  2.259250e+11  2.461950e+11  2.895670e+11  ...
# 16  1.986438e+09  1.695315e+09  2.274558e+09  1.598076e+09  2.169627e+09  ...
#
# ...
