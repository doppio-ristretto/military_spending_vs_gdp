# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
gdp_file = "GDP By Country.csv"
gdp_df = pd.read_csv(gdp_file)
gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  ...  \
# 0          NaN          NaN          NaN          NaN           NaN  ...
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09  ...
# 2          NaN          NaN          NaN          NaN           NaN  ...
# 3          NaN          NaN          NaN          NaN           NaN  ...
# 4          NaN          NaN          NaN          NaN           NaN  ...
#
# ...

# %%
gdp_new = gdp_df.drop(columns=['Country Code','Indicator Name','Indicator Code'])
gdp_new.drop('2018',axis=1, inplace=True)

# %%
rename = gdp_new.rename(columns={'Country Name':'Country'})
rename2 = rename.set_index('Country')
rename3 = rename2.add_suffix(' gdp')

# %%
clean_gdp = rename3.dropna()
final_gdp = clean_gdp.drop(clean_gdp.columns.to_series()["1960":"1989"],axis=1)

# %%
final_gdp.to_csv('clean_gdp_file.csv')

# %%
clean_gdp_file = pd.read_csv('clean_gdp_file.csv')
clean_gdp_file
# Out:
#                             Country      1989 gdp      1990 gdp      1991 gdp  \
# 0                         Australia  2.993180e+11  3.108380e+11  3.253580e+11
# 1                           Austria  1.331060e+11  1.664630e+11  1.737940e+11
# 2                           Burundi  1.113924e+09  1.132101e+09  1.167398e+09
# 3                           Belgium  1.651000e+11  2.064310e+11  2.116380e+11
# 4                             Benin  1.502294e+09  1.959965e+09  1.986438e+09
# ..                              ...           ...           ...           ...
# 119  St. Vincent and the Grenadines  2.147450e+08  2.403653e+08  2.548296e+08
# 120                           World  2.010400e+13  2.260710e+13  2.395130e+13
# 121                    South Africa  1.289030e+11  1.155530e+11  1.239430e+11
# 122                          Zambia  3.998638e+09  3.285217e+09  3.378882e+09
# 123                        Zimbabwe  8.286323e+09  8.783817e+09  8.641482e+09
#
# ...
