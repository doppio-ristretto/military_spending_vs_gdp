# %%
#1990 - 2017
import pandas as pd

# %%
population_data = pd.read_csv("population.csv",skiprows=4)
population_data.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
new_df = population_data.drop(columns=['Country Code','Indicator Code','Indicator Name', '1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','2018','2019','Unnamed: 64'])
renamed_population_df = new_df.rename(columns={"Country Name":"Country"}).set_index("Country")
#renamed_population_df

final_population_df = renamed_population_df.dropna(how = "all")
final = final_population_df.add_suffix('_Population')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-862b855bb5bc> in <module>
# ----> 1 new_df = population_data.drop(columns=['Country Code','Indicator Code','Indicator Name', '1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','2018','2019','Unnamed: 64_Population'])
#       2 renamed_population_df = new_df.rename(columns={"Country Name":"Country"}).set_index("Country")
#       3 #renamed_population_df
#       4
#       5 final_population_df = renamed_population_df.dropna(how = "all")
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# ...

# %%
final.to_csv('cleanpopulation.csv')
