# %%
#1990 - 2017
import pandas as pd

# %%
population_data = pd.read_csv("population.csv",skiprows=4)
population_data.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2011  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    102046.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  30117413.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  24220661.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2905195.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     83747.0
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
new_df = population_data.drop(columns=['Country Code','Indicator Code','Indicator Name', '1960','1961','1962','1963','1964','1965','1966','1967','1968','1969','1970','1971','1972','1973','1974','1975','1976','1977','1978','1979','1980','1981','1982','1983','1984','1985','1986','1987','1988','1989','2018','2019'])
renamed_population_df = new_df.rename(columns={"Country Name":"Country"}).set_index("Country")
#renamed_population_df

final_population_df = renamed_population_df.dropna(how = "all")
final = final_population_df.add_suffix(' (Population)')
# Out:
#               1990 (Population)  1991 (Population)  1992 (Population)  \
# Country
# Aruba                   62149.0            64622.0            68235.0
# Afghanistan          12412308.0         13299017.0         14485546.0
# Angola               11848386.0         12248901.0         12657366.0
# Albania               3286542.0          3266790.0          3247039.0
# Andorra                 54509.0            56671.0            58888.0
# ...                         ...                ...                ...
# Kosovo                1862000.0          1898000.0          1932000.0
# Yemen, Rep.          11709993.0         12302124.0         12954155.0
# South Africa         36800509.0         37718950.0         38672607.0
# Zambia                8036845.0          8246656.0          8451347.0
# Zimbabwe             10432421.0         10680995.0         10900502.0
#
#               1993 (Population)  1994 (Population)  1995 (Population)  \
# Country
# ...

# %%
final.to_csv('cleanpopulation.csv')
